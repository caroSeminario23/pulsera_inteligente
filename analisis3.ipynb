# %%
import pandas as pd

# Leer el archivo csv
data1 = pd.read_csv('Dataset_medio_limpio_filtrado.csv')
data1
# Out:
#                Disease  Fever  Difficulty Breathing  Age  Gender  \
# 0            Influenza      1                     1   19       1
# 1               Asthma      1                     1   25       0
# 2               Eczema      1                     0   25       1
# 3            Influenza      1                     1   25       1
# 4               Asthma      1                     1   28       0
# ..                 ...    ...                   ...  ...     ...
# 151        Tonsillitis      1                     0   70       1
# 152  Williams Syndrome      0                     0   70       1
# 153             Stroke      1                     0   80       1
# 154             Stroke      1                     0   85       0
# 155             Stroke      1                     0   90       1
#
#      Blood Pressure  Cholesterol Level  Outcome Variable  Disease_code
# 0                 0                  1                 1             0
# ...

# %%
# visualizar los datos unicos de la columna disease
data1['Disease'].unique()
# Out:
# array(['Influenza', 'Asthma', 'Eczema', 'Depression', 'Liver Cancer',
#        'Stroke', 'Urinary Tract Infection', 'Bipolar Disorder',
#        'Bronchitis', 'Cerebral Palsy', 'Colorectal Cancer',
#        'Hypertensive Heart Disease', 'Multiple Sclerosis',
#        'Myocardial Infarction (Heart...', 'Urinary Tract Infection (UTI)',
#        'Common Cold', 'Migraine', 'Pneumonia', 'Cirrhosis',
#        'Conjunctivitis (Pink Eye)', 'Gastroenteritis', 'Hyperthyroidism',
#        'Kidney Cancer', 'Liver Disease', 'Malaria', 'Pancreatitis',
#        'Rheumatoid Arthritis', 'Spina Bifida', 'Ulcerative Colitis',
#        'Anxiety Disorders', 'Diabetes', 'Osteoarthritis',
#        'Klinefelter Syndrome', 'Chickenpox', 'Coronary Artery Disease',
#        'Eating Disorders (Anorexia,...', 'Fibromyalgia', 'Hemophilia',
#        'Hypoglycemia', 'Lymphoma', 'Psoriasis', 'Tuberculosis',
#        'Hypothyroidism', 'Kidney Disease', 'Allergic Rhinitis',
# ...

# %% [markdown]
# ## A seleccionar:
# - Influenza
# - Asthma
# - Depression
# - Bronchitis
# - Hypertensive Heart Disease
# - Migraine
# - Pneumonia
# - Diabetes
# - Eating Disorders
# - Allergic Rhinitis
# - Hypertension

# %%
# Crear un nuevo dataset con los registros que contengan la enfermedad 'Hypertension' o 'Diabetes'
data2 = data1[(data1['Disease'] == 'Influenza') | (data1['Disease'] == 'Asthma')| (data1['Disease'] == 'Migraine') | (data1['Disease'] == 'Pneumonia') | (data1['Disease'] == 'Diabetes') | (data1['Disease'] == 'Eating Disorders') | (data1['Disease'] == 'Hypertension')]

# %%
data2
# Out:
#           Disease  Fever  Difficulty Breathing  Age  Gender  Blood Pressure  \
# 0       Influenza      1                     1   19       1               0
# 1          Asthma      1                     1   25       0               1
# 3       Influenza      1                     1   25       1               1
# 4          Asthma      1                     1   28       0               2
# 9          Asthma      1                     1   30       1               1
# 17      Influenza      1                     0   30       0               2
# 18      Influenza      1                     1   30       1               1
# 23       Migraine      1                     0   31       1               1
# 24      Pneumonia      1                     1   32       1               2
# 25         Asthma      1                     1   35       0               1
# 35       Migraine      0                     0   35       0               2
# ...

# %%
# Borrar los registros con id 1, 50-53
data3 = data2.drop([1,50,51,52,53])
data3
# Out:
#           Disease  Fever  Difficulty Breathing  Age  Gender  Blood Pressure  \
# 0       Influenza      1                     1   19       1               0
# 3       Influenza      1                     1   25       1               1
# 4          Asthma      1                     1   28       0               2
# 9          Asthma      1                     1   30       1               1
# 17      Influenza      1                     0   30       0               2
# 18      Influenza      1                     1   30       1               1
# 23       Migraine      1                     0   31       1               1
# 24      Pneumonia      1                     1   32       1               2
# 25         Asthma      1                     1   35       0               1
# 35       Migraine      0                     0   35       0               2
# 36       Migraine      1                     0   35       0               2
# ...

# %%
# Exportar el dataset a un archivo csv
data3.to_csv('Dataset_medio_limpio_filtrado2.csv', index=False)

# %%
# Cuantas veces se repite cada valor de 'Disease'
data3['Disease'].value_counts()
# Out:
# Disease
# Asthma          6
# Influenza       5
# Migraine        5
# Pneumonia       5
# Diabetes        5
# Hypertension    5
# Name: count, dtype: int64
