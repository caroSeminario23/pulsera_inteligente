# %%
import pandas as pd

# Leer un archivo csv
datos1 = pd.read_csv('Dataset_medio_limpio.csv')
datos1
# Out:
#                Disease  Fever  Difficulty Breathing  Age  Gender  \
# 0            Influenza      1                     1   19       1
# 1          Common Cold      0                     0   25       1
# 2               Eczema      0                     0   25       1
# 3               Asthma      1                     1   25       0
# 4               Eczema      1                     0   25       1
# ..                 ...    ...                   ...  ...     ...
# 294        Tonsillitis      1                     0   70       1
# 295  Williams Syndrome      0                     0   70       1
# 296             Stroke      1                     0   80       1
# 297             Stroke      1                     0   85       0
# 298             Stroke      1                     0   90       1
#
#      Blood Pressure  Cholesterol Level  Outcome Variable  Disease_code
# 0                 0                  1                 1             0
# ...

# %%
# Filtrar las filas que tengan en 'Outcome Variable' el valor de 1
datos2 = datos1[datos1['Outcome Variable'] == 1]
datos2
# Out:
#                Disease  Fever  Difficulty Breathing  Age  Gender  \
# 0            Influenza      1                     1   19       1
# 3               Asthma      1                     1   25       0
# 4               Eczema      1                     0   25       1
# 5            Influenza      1                     1   25       1
# 7               Asthma      1                     1   28       0
# ..                 ...    ...                   ...  ...     ...
# 294        Tonsillitis      1                     0   70       1
# 295  Williams Syndrome      0                     0   70       1
# 296             Stroke      1                     0   80       1
# 297             Stroke      1                     0   85       0
# 298             Stroke      1                     0   90       1
#
#      Blood Pressure  Cholesterol Level  Outcome Variable  Disease_code
# 0                 0                  1                 1             0
# ...

# %%
# Exportar el archivo a un csv
datos2.to_csv('Dataset_medio_limpio_filtrado.csv', index=False)

# %%
# Cuantas veces se repite cada valor de 'Disease'
datos2['Disease'].value_counts()
# Out:
# Disease
# Asthma                          11
# Stroke                           7
# Osteoporosis                     6
# Influenza                        5
# Migraine                         5
#                                 ..
# Cataracts                        1
# Pneumocystis Pneumonia (PCP)     1
# Scoliosis                        1
# Sickle Cell Anemia               1
# Williams Syndrome                1
# Name: count, Length: 77, dtype: int64
